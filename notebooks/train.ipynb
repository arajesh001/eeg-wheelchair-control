# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "functions"))

# %%
import numpy as np
from dataset import load_dataset
from train import run_loso

# %%
X, y, subjects = load_dataset("../data/processed")
print(X.shape, y.shape, subjects.shape)
# Out:
# (2592, 22, 65, 626) (2592,) (2592,)

# %%
X, y, subjects = load_dataset("processed_small")
accuracies, mean = run_loso(X, y, subjects, n_epochs=50, batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 X, y, subjects = load_dataset("processed_small")
# ----> 2 accuracies, mean = run_loso(X, y, subjects, n_epochs=50, batch_size=32)
#
# File ~/eeg-wheelchair-control/functions/train.py:171, in run_loso(X, y, subjects, n_epochs, batch_size)
#     169 # train n_epochs
#     170 for epoch in range(1, n_epochs + 1):
# --> 171     loss = train(model, train_loader, optimizer, loss_fn, device)
#     172     print(epoch, loss)
#     174 # eval
#
# File ~/eeg-wheelchair-control/functions/train.py:73, in train(model, dataloader, optimizer, loss_fn, device)
#      70 optimizer.zero_grad()
#      72 # get model predictions
# ---> 73 preds = model(X_batch)
#      75 # compute cross entropy loss
#      76 loss = loss_fn(preds, y_batch)
#
# ...
