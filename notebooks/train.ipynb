# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "functions"))

# %%
import numpy as np
from dataset import load_dataset, EEGDataset
from train import run_loso, run_loso_optimized

# %%
X, y, subjects = load_dataset("processed_small")
accuracies, mean = run_loso(X, y, subjects, n_epochs=50, batch_size=32)
# Out:
# 1 49.55273714330461
# 2 16.164983563952976
# 3 7.114597916603088
# 4 2.5462235808372498
# 5 1.5166111456023321
# 6 0.6609567490716776
# 7 0.4353366659488529
# 8 0.20949828410003749
# 9 0.10512509122620234
# 10 0.05624646167497202
# 11 0.04548814054255167
# 12 0.06354906662858816
# 13 0.03435479483677126
# 14 0.02770629318870811
# 15 0.05270753133421143
# 16 0.015320259365075294
# 17 0.016591476854753436
# 18 0.035513560703596646
# 19 0.0279892325007596
# 20 0.042503610837027535
# 21 0.03606021122161312
# 22 0.08984406609912791
# 23 0.017510543275825005
# 24 0.035105458094525
# 25 0.03092622834194319
# 26 0.04776091148283336
# 27 0.029917116691245207
# 28 0.1098569674910929
# 29 0.37264603809065494
# 30 0.6604409392037067
# 31 1.556801530222098
# 32 0.9776050101500005
# 33 0.5137863072256247
# 34 0.3546559532743332
# 35 0.25817452703227495
# 36 0.13004536711948353
# 37 0.1889293015852268
# 38 0.3871247492267382
# 39 0.25886618116055615
# 40 0.2284932802050024
# 41 0.08985040828949625
# ...

# %%
subject_ids = list(range(1, 10))
accuracies, mean = run_loso_optimized(subject_ids, n_epochs=50, batch_size=32, data_dir="../data/processed_per_subject")
# Out:
# /Users/ashvath/eeg-wheelchair-control/functions/dataset.py:243: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:219.)
#   x = torch.from_numpy(self.X_list[subject_idx][local_idx]).float()
# [Subject 1] Epoch 1/50 | Loss: 2.3144
# [Subject 1] Epoch 2/50 | Loss: 1.1483
# [Subject 1] Epoch 3/50 | Loss: 0.6854
# [Subject 1] Epoch 4/50 | Loss: 0.4895
# [Subject 1] Epoch 5/50 | Loss: 0.2738
# [Subject 1] Epoch 6/50 | Loss: 0.1822
# [Subject 1] Epoch 7/50 | Loss: 0.1285
# [Subject 1] Epoch 8/50 | Loss: 0.0967
# [Subject 1] Epoch 9/50 | Loss: 0.0746
# [Subject 1] Epoch 10/50 | Loss: 0.0657
# ...

# %%
import csv

results = {
    1: 0.2743,
    2: 0.2708,
    3: 0.3021,
    4: 0.2535,
    5: 0.2257,
    6: 0.2778,
    7: 0.3125,
    8: 0.3056,
    9: 0.3229,
}

with open("../results/baseline_loso_run_1.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["subject", "accuracy"])
    for subj, acc in results.items():
        writer.writerow([subj, acc])

# %% [markdown]
# # 3 subject w/early stopping

# %%
subject_ids = [1, 2, 3]
accuracies, mean = run_loso_optimized(subject_ids, n_epochs=50, batch_size=32, data_dir="../data/processed_per_subject")
# Out:
# [Subject 1] Epoch 1/50 | Loss: 2.8010
# [Subject 1] Epoch 2/50 | Loss: 1.0650
# [Subject 1] Epoch 3/50 | Loss: 0.5971
# [Subject 1] Epoch 4/50 | Loss: 0.3505
# [Subject 1] Epoch 5/50 | Loss: 0.2785
# [Subject 1] Epoch 6/50 | Loss: 0.1068
# [Subject 1] Epoch 7/50 | Loss: 0.0579
# [Subject 1] Epoch 8/50 | Loss: 0.0466
# [Subject 1] Epoch 9/50 | Loss: 0.0373
# [Subject 1] Epoch 10/50 | Loss: 0.0316
# [Subject 1] Epoch 11/50 | Loss: 0.0271
# [Subject 1] Epoch 12/50 | Loss: 0.0225
# [Subject 1] Epoch 13/50 | Loss: 0.0207
# [Subject 1] Epoch 14/50 | Loss: 0.0180
# [Subject 1] Epoch 15/50 | Loss: 0.0169
# [Subject 1] Epoch 16/50 | Loss: 0.0162
# [Subject 1] Epoch 17/50 | Loss: 0.0137
# [Subject 1] Epoch 18/50 | Loss: 0.0119
# [Subject 1] Epoch 19/50 | Loss: 0.0111
# [Subject 1] Epoch 20/50 | Loss: 0.0100
# [Subject 1] Epoch 21/50 | Loss: 0.0094
# [Subject 1] Epoch 22/50 | Loss: 0.0097
# [Subject 1] Epoch 23/50 | Loss: 0.0090
# [Subject 1] Epoch 24/50 | Loss: 0.0081
# ...

# %% [markdown]
# # 3 subject w/validation loss stopping & L2 regularization

# %%
subject_ids = [1, 2, 3]
accuracies, mean = run_loso_optimized(subject_ids, n_epochs=50, batch_size=32, data_dir="../data/processed_per_subject")
# Out:
# /Users/ashvath/eeg-wheelchair-control/functions/dataset.py:243: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:219.)
#   x = torch.from_numpy(self.X_list[subject_idx][local_idx]).float()
# [Subject 1] Epoch 1/50 | Train Loss: 2.0439 | Val Loss: 1.3882
# [Subject 1] Epoch 2/50 | Train Loss: 1.3597 | Val Loss: 1.3919
# [Subject 1] Epoch 3/50 | Train Loss: 1.3582 | Val Loss: 1.3809
# [Subject 1] Epoch 4/50 | Train Loss: 1.3372 | Val Loss: 1.3914
# [Subject 1] Epoch 5/50 | Train Loss: 1.2891 | Val Loss: 1.3795
# [Subject 1] Epoch 6/50 | Train Loss: 1.2543 | Val Loss: 1.3908
# ...

# %% [markdown]
# # New CNN architecture

# %%
subject_ids = [1, 2, 3]
accuracies, mean = run_loso_optimized(subject_ids, n_epochs=50, batch_size=32, data_dir="../data/processed_per_subject")
# Out:
# /Users/ashvath/eeg-wheelchair-control/functions/dataset.py:243: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:219.)
#   x = torch.from_numpy(self.X_list[subject_idx][local_idx]).float()
# [Subject 1] Epoch 1/50 | Train Loss: 1.8371 | Val Loss: 1.6892
# [Subject 1] Epoch 2/50 | Train Loss: 0.9038 | Val Loss: 1.9907
# [Subject 1] Epoch 3/50 | Train Loss: 0.6039 | Val Loss: 2.1069
# [Subject 1] Epoch 4/50 | Train Loss: 0.3660 | Val Loss: 2.2878
# [Subject 1] Epoch 5/50 | Train Loss: 0.2249 | Val Loss: 2.4708
# [Subject 1] Epoch 6/50 | Train Loss: 0.1746 | Val Loss: 2.5495
# ...
